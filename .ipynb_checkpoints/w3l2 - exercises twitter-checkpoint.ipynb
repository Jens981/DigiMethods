# %%
#Find the Twitter account of the University of Copenhagen's 
#Faculty of Social Science by hand and get their Twitter account 
#information using tweepy functionality. Remember that you just 
#started a new Jupyter Notebook, so you will have to load the necessary 
#modules and set up your authentication with the Twitter API.
import tweepy
print(tweepy.__version__)
# Out:
# 3.8.0

# %%
from AppCred import CONSUMER_KEY, CONSUMER_SECRET
from AppCred import ACCESS_TOKEN, ACCESS_TOKEN_SECRET

# %%
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

# %%
api = tweepy.API(auth)

# %%
example_user = api.get_user("vicariousveblen")

# %%
example_user = api.get_user("uni_copenhagen")

# %%
Trump = api.get_user("realDonaldTrump")

# %%
Trump.description
# Out:
# '45th President of the United States of America🇺🇸'

# %%
print("The user RealDonaldTrump has "+str(Trump.followers_count)+" followers")
# Out:
# The user RealDonaldTrump has 72807689 followers

# %%
example_user.description
# Out:
# 'Copenhagen, Denmark'

# %%
Trump_tweets = api.user_timeline("realDonaldTrump", count = 50)

# %%
import nltk
from nltk.corpus import stopwords

def user_gist(user_timeline):
    
    # set up empty containers we will need throughout the loop
    word_freq = {}
    word_list = []
    gist = []
    
    # FIRST, loop through tweets in the timeline
    for tweet in user_timeline:
        # split up tweets into lists of words
        tweet_words = tweet.text.split()
        # and combine into one big list using `extend` command
        word_list.extend(tweet_words)
        
    word_list2 = [word for word in word_list if word not in stopwords.words('english')]
    
    # SECOND, loop through list of words in tweets
    for w in word_list2:
        # add each unique word and its `count` to the dictionary `word_frequency`
        if w not in word_freq:
            word_freq[w] = word_list2.count(w)

    #looping through the dictionary and adding each value, key pair to the list
    for key in word_freq:
        gist.append((word_freq[key], key))

    #sorting the list
    gist.sort()
    #reversing the sort to be largest to smallest
    gist.reverse()

    #returning the list
    return gist

# %%
user_gist(Trump_tweets)
# Out:
# [(31, 'RT'),
#  (5, 'I'),
#  (4, 'Trump'),
#  (4, 'Russia'),
#  (4, '@DanScavino:'),
#  (3, '▶️'),
#  (3, 'reason'),
#  (3, 'great'),
#  (3, 'every'),
#  (3, 'back'),
#  (3, 'The'),
#  (3, 'Thank'),
#  (3, 'Taliban'),
#  (3, 'State'),
#  (3, 'Bernie'),
#  (3, '@realDonaldTrump'),
#  (3, '@BuckSexton:'),
#  (3, '&amp;'),
#  (2, 'want'),
#  (2, 'using'),
#  (2, 'understanding'),
#  (2, 'trying'),
#  (2, 'to…'),
#  (2, 'tonight'),
#  (2, 'reduction'),
#  (2, 'paying'),
#  (2, 'party'),
#  (2, 'others'),
#  (2, 'midnight'),
#  (2, 'made'),
#  (2, 'low'),
#  (2, 'jobs'),
#  (2, 'cut'),
#  (2, 'begin'),
#  (2, 'added'),
#  (2, 'across'),
#  (2, 'What'),
#  (2, 'U.S.'),
#  (2, 'Nevada!'),
#  (2, 'Great'),
#  (2, 'Fake'),
#  (2, 'Democrats'),
#  (2, 'Clinton'),
#  (2, 'Afghan'),
#  (1, '✅More'),
#  (1, '✅50-year'),
#  (1, '✅225,000'),
#  (1, '⚠️#TDSWarning🤯'),
#  (1, '“reduction'),
#  (1, '“When'),
#  (1, '“Wait,'),
#  (1, '“She'),
#  (1, '“Our'),
#  (1, '“I’m'),
#  (1, '“I'),
#  (1, '“An'),
#  (1, 'zero…'),
#  (1, 'y…'),
#  (1, 'you…'),
#  (1, 'you’re'),
#  (1, 'you,'),
#  (1, 'you!'),
#  (1, 'years,'),
#  (1, 'workers'),
#  (1, 'wonderful'),
#  (1, 'within'),
#  (1, 'window....and'),
#  (1, 'win'),
#  (1, 'whoever'),
#  (1, 'weeks!'),
#  (1, 'week-long'),
#  (1, 'week'),
#  (1, 'walk'),
#  (1, 'w/military'),
#  (1, 'vital'),
#  (1, 'violence”'),
#  (1, 'violence"'),
#  (1, 'violence'),
#  (1, 'via'),
#  (1, 'vampire'),
#  (1, 'us'),
#  (1, 'upcoming'),
#  (1, 'unemployment'),
#  (1, 't…'),
#  (1, 'tremendous'),
#  (1, 'trapped'),
#  (1, 'time.'),
#  (1, 'time'),
#  (1, 'tied'),
#  (1, 'th…'),
#  (1, 'thought'),
#  (1, 'think'),
#  (1, 'the…'),
#  (1, 'that…'),
#  (1, 'technology'),
#  (1, 'taxes,'),
#  (1, 'table'),
#  (1, 'sure'),
#  (1, 'support'),
#  (1, 'succeeding,'),
#  (1, 'strong,'),
#  (1, 'stinks.”'),
#  (1, 'still'),
#  (1, 'state'),
#  (1, 'starts...'),
#  (1, 'start'),
#  (1, 'stand'),
#  (1, 'soon!'),
#  (1, 'somebody'),
#  (1, 'sold'),
#  (1, 'social'),
#  (1, 'soaring'),
#  (1, 'sit'),
#  (1, 'significant,'),
#  (1, 'significant'),
#  (1, 'sign'),
#  (1, 'shitty'),
#  (1, 'share'),
#  (1, 'servicemembers'),
#  (1, 'servant.'),
#  (1, 'see…'),
#  (1, 'security'),
#  (1, 'saying'),
#  (1, 'safe.'),
#  (1, 'right'),
#  (1, 'return…'),
#  (1, 'request,'),
#  (1, 'report'),
#  (1, 'remodeling'),
#  (1, 'regulations'),
#  (1, 'reelected'),
#  (1, 'record'),
#  (1, 'realize'),
#  (1, 'ready'),
#  (1, 'reached'),
#  (1, 'ratings'),
#  (1, 'race.'),
#  (1, 'quit'),
#  (1, 'put,'),
#  (1, 'put'),
#  (1, 'puppet"'),
#  (1, 'public'),
#  (1, 'proud,'),
#  (1, 'protocol'),
#  (1, 'protected'),
#  (1, 'properly'),
#  (1, 'progress.'),
#  (1, 'probably'),
#  (1, 'prefers'),
#  (1, 'ports'),
#  (1, 'point'),
#  (1, 'plot'),
#  (1, 'people,'),
#  (1, 'pathetic'),
#  (1, 'part…'),
#  (1, 'particular'),
#  (1, 'pantry'),
#  (1, 'panic'),
#  (1, 'one'),
#  (1, 'of…'),
#  (1, 'often'),
#  (1, 'officials…'),
#  (1, 'official:'),
#  (1, 'officers'),
#  (1, 'obvious'),
#  (1, 'number'),
#  (1, 'next'),
#  (1, 'new'),
#  (1, 'never'),
#  (1, 'negotiators'),
#  (1, 'negotiating'),
#  (1, 'need'),
#  (1, 'nearly'),
#  (1, 'nationwide'),
#  (1, 'misinformation'),
#  (1, 'mine,'),
#  (1, 'millions'),
#  (1, 'million'),
#  (1, 'memes'),
#  (1, 'meme'),
#  (1, 'media'),
#  (1, 'making'),
#  (1, 'l…'),
#  (1, 'luck'),
#  (1, 'love,'),
#  (1, 'losers,'),
#  (1, 'long'),
#  (1, 'local'),
#  (1, 'living'),
#  (1, 'list'),
#  (1, 'like'),
#  (1, 'life.'),
#  (1, 'let’s'),
#  (1, 'letter'),
#  (1, 'leave'),
#  (1, 'leaders'),
#  (1, 'lawyer,'),
#  (1, 'launched'),
#  (1, 'know:'),
#  (1, 'know'),
#  (1, 'kept'),
#  (1, 'jury.'),
#  (1, 'in…'),
#  (1, 'investigation'),
#  (1, 'interests'),
#  (1, 'interesting'),
#  (1, 'information'),
#  (1, 'influencers'),
#  (1, 'implemented'),
#  (1, 'h…'),
#  (1, 'https://t.co/uEFp9022it'),
#  (1, 'https://t.co/pHdwJ9KN8c'),
#  (1, 'https://t.co/oubu6tCG4m'),
#  (1, 'https://t.co/mD4giyC1tg'),
#  (1, 'https://t.co/lRBLCr5cga'),
#  (1, 'https://t.co/ksJRH2UzlE'),
#  (1, 'https://t.co/kTbD16zRh4'),
#  (1, 'https://t.co/gfbLh8w4ox'),
#  (1, 'https://t.co/fegmOvCL5m'),
#  (1, 'https://t.co/eDf8ltInmH'),
#  (1, 'https://t.co/UM2iDYfaPy'),
#  (1, 'https://t.co/T…'),
#  (1, 'https://t.co/M4KVeGZsqo'),
#  (1, 'https://t.co/EBVrig52ne'),
#  (1, 'https://t.co/CUj7WlvK29'),
#  (1, 'https://t.co/8DATLsqJZc'),
#  (1, 'https://t.co/4GeJMvTO2j'),
#  (1, 'https://t.co/3i6tgfqrRl'),
#  (1, 'https://t.co/2FeFybASpd'),
#  (1, 'honor'),
#  (1, 'honey…'),
#  (1, 'honest:'),
#  (1, 'homeland'),
#  (1, 'hi…'),
#  (1, 'historic,'),
#  (1, 'he’s'),
#  (1, 'help'),
#  (1, 'healthy'),
#  (1, 'haven’…'),
#  (1, 'hardworking'),
#  (1, 'happens'),
#  (1, 'hands'),
#  (1, 'guy'),
#  (1, 'guests'),
#  (1, 'growing'),
#  (1, 'ground'),
#  (1, 'got'),
#  (1, 'given…'),
#  (1, 'get'),
#  (1, 'garlic'),
#  (1, 'friend'),
#  (1, 'forces'),
#  (1, 'flag'),
#  (1, 'first'),
#  (1, 'find'),
#  (1, 'fighting'),
#  (1, 'fast!'),
#  (1, 'entering,'),
#  (1, 'employment,'),
#  (1, 'elites'),
#  (1, 'electronic'),
#  (1, 'election'),
#  (1, 'economy...'),
#  (1, 'economy!'),
#  (1, 'economy'),
#  (1, 'don’t'),
#  (1, 'done'),
#  (1, 'donated'),
#  (1, 'disinformation'),
#  (1, 'didn’t'),
#  (1, 'devious'),
#  (1, 'detect'),
#  (1, 'destroy'),
#  (1, 'deployed'),
#  (1, 'delighted'),
#  (1, 'defend'),
#  (1, 'decades'),
#  (1, 'day.'),
#  (1, 'cycle'),
#  (1, 'crimi…'),
#  (1, 'create…'),
#  (1, 'cover-up'),
#  (1, 'cooperation'),
#  (1, 'convenient'),
#  (1, 'continue'),
#  (1, 'consideration'),
#  (1, 'conflict,'),
#  (1, 'confidence'),
#  (1, 'community,'),
#  (1, 'come'),
#  (1, 'coincidence,'),
#  (1, 'coincidence'),
#  (1, 'claiming'),
#  (1, 'citizens'),
#  (1, 'choked!'),
#  (1, 'candidates'),
#  (1, 'campaign'),
#  (1, 'called'),
#  (1, 'by…'),
#  (1, 'build'),
#  (1, 'bros'),
#  (1, 'boomed!'),
#  (1, 'birthday'),
#  (1, 'bad'),
#  (1, 'backgrounds'),
#  (1, 'background,'),
#  (1, 'assistance'),
#  (1, 'appointment'),
#  (1, 'announced'),
#  (1, 'announce'),
#  (1, 'angry'),
#  (1, 'always'),
#  (1, 'allows'),
#  (1, 'agreed'),
#  (1, 'again,'),
#  (1, 'advanced'),
#  (1, 'addiction'),
#  (1, 'YOU'),
#  (1, 'With'),
#  (1, 'Witch'),
#  (1, 'We'),
#  (1, 'WITH'),
#  (1, 'WINNING'),
#  (1, 'WAY!'),
#  (1, 'Violence"'),
#  (1, 'Vets,'),
#  (1, 'Vegas,'),
#  (1, 'Uranium'),
#  (1, 'Unified'),
#  (1, 'Unemployment'),
#  (1, 'US-Taliban'),
#  (1, 'UNTIL'),
#  (1, 'Trump,'),
#  (1, 'Trey'),
#  (1, 'This…'),
#  (1, 'They'),
#  (1, 'There'),
#  (1, 'Then'),
#  (1, 'Te…'),
#  (1, 'TRADE'),
#  (1, 'TIME'),
#  (1, 'THE'),
#  (1, 'THANK'),
#  (1, 'TARGETED'),
#  (1, 'Sympat…'),
#  (1, 'Starting'),
#  (1, 'Sr.'),
#  (1, 'So'),
#  (1, 'Slime),'),
#  (1, 'Slams'),
#  (1, 'Simply'),
#  (1, "Sheriff's"),
#  (1, 'San…'),
#  (1, 'San'),
#  (1, 'SUCH'),
#  (1, 'Russian'),
#  (1, 'Russia/Sanders,'),
#  (1, 'Republicans'),
#  (1, 'Rally!'),
#  (1, 'Rally'),
#  (1, 'Putin,'),
#  (1, "Putin's"),
#  (1, 'President'),
#  (1, 'Poll'),
#  (1, 'PATRIOTS.'),
#  (1, 'Our'),
#  (1, 'Obama'),
#  (1, 'OUR'),
#  (1, 'ON'),
#  (1, 'Numbers'),
#  (1, 'Now,'),
#  (1, 'Nov…'),
#  (1, 'November.'),
#  (1, 'Nothing'),
#  (1, 'New'),
#  (1, 'Nevada'),
#  (1, 'NYT'),
#  (1, 'NOTHING.”'),
#  (1, 'NEED'),
#  (1, 'Mueller'),
#  (1, 'Mitch'),
#  (1, 'Military'),
#  (1, 'Mike!'),
#  (1, 'Method'),
#  (1, 'Meeting'),
#  (1, 'Media,'),
#  (1, 'Mastermind:'),
#  (1, 'MY'),
#  (1, 'MSDNC'),
#  (1, 'MEXICO,'),
#  (1, 'Liberals'),
#  (1, 'Law'),
#  (1, 'Las'),
#  (1, 'Klobuchar'),
#  (1, 'Jobs,'),
#  (1, 'January'),
#  (1, 'JAG'),
#  (1, 'Individuals'),
#  (1, 'Incredible'),
#  (1, 'In'),
#  (1, 'Illegal'),
#  (1, 'IF'),
#  (1, 'ICE.'),
#  (1, 'ICE'),
#  (1, 'Hunt!'),
#  (1, 'Hoax'),
#  (1, 'His'),
#  (1, 'Hillary'),
#  (1, 'Highest'),
#  (1, 'Hey,'),
#  (1, "Here's"),
#  (1, 'Happy'),
#  (1, 'Great!'),
#  (1, 'Gowdy'),
#  (1, 'Good'),
#  (1, 'GUY.”'),
#  (1, 'GREAT'),
#  (1, 'Friend'),
#  (1, 'Four'),
#  (1, 'Foundation'),
#  (1, 'For'),
#  (1, 'Flouting'),
#  (1, 'First'),
#  (1, 'FORMALLY'),
#  (1, 'FARMERS'),
#  (1, 'FAN'),
#  (1, 'Everything'),
#  (1, 'Economy,'),
#  (1, 'EVER!'),
#  (1, 'Donald'),
#  (1, 'Do'),
#  (1, 'Diego'),
#  (1, 'Did'),
#  (1, 'Dept.'),
#  (1, 'Department'),
#  (1, 'Democra…'),
#  (1, 'Democrats’'),
#  (1, 'Democrats,'),
#  (1, 'Democrat'),
#  (1, 'Decision'),
#  (1, 'DNI.'),
#  (1, 'DEALS'),
#  (1, 'Crazy'),
#  (1, 'Courthouse,'),
#  (1, 'Consumer'),
#  (1, 'Congress'),
#  (1, 'Coming'),
#  (1, 'Colorado.'),
#  (1, 'Cleaning'),
#  (1, 'CHINA,'),
#  (1, 'CANADA…'),
#  (1, 'CA'),
#  (1, 'Buttigieg,'),
#  (1, 'Bloomberg'),
#  (1, 'Bill'),
#  (1, 'Biden,'),
#  (1, 'Barr.'),
#  (1, 'BIG'),
#  (1, 'BAM!'),
#  (1, 'At'),
#  (1, 'As'),
#  (1, 'Arrests'),
#  (1, 'Another'),
#  (1, 'Angela!'),
#  (1, 'Amusing:'),
#  (1, 'America’s'),
#  (1, 'Americans'),
#  (1, 'American'),
#  (1, 'Aliens'),
#  (1, 'After'),
#  (1, 'Afghanistan'),
#  (1, 'Administration'),
#  (1, 'AS'),
#  (1, 'ALL'),
#  (1, 'AID'),
#  (1, 'ADDITIONAL'),
#  (1, 'A.B.Stoddard'),
#  (1, 'A'),
#  (1, '@trish_regan'),
#  (1, '@statedeptspox:'),
#  (1, '@senatemajldr’s'),
#  (1, '@senatemajldr:'),
#  (1, '@seanmdav:'),
#  (1, '@seanhannity'),
#  (1, '@realDonaldTrump.”'),
#  (1, '@realDonaldTrump,'),
#  (1, '@prayingmedic:'),
#  (1, '@katrina_wiser:'),
#  (1, '@k_ovfefe2:'),
#  (1, '@johncardillo:'),
#  (1, '@foxnews'),
#  (1, '@charliekirk11:'),
#  (1, '@WSJ'),
#  (1, '@USCGReserve!'),
#  (1, '@TeamCavuto'),
#  (1, '@SteveDaines:'),
#  (1, '@SenateGOP:'),
#  (1, '@SenateGOP'),
#  (1, '@SenBillCassidy:'),
#  (1, '@SecPompeo:'),
#  (1, '@SecKermani:'),
#  (1, '@RoyBlunt:'),
#  (1, '@RealJamesWoods:'),
#  (1, '@RFERL:'),
#  (1, '@MikeBloomberg🤗'),
#  (1, '@MikeBloomberg👏'),
#  (1, '@McConnellPress:'),
#  (1, '@LucasFoxNews:'),
#  (1, '@KimStrassel:'),
#  (1, '@JudgeJeanine'),
#  (1, '@JuddPDeere45:'),
#  (1, '@JohnBoozman:'),
#  (1, '@JimInhofe:'),
#  (1, '@Jamierodr14:'),
#  (1, '@FoxNews'),
#  (1, '@CNN'),
#  (1, '@ByronYork:'),
#  (1, '79th'),
#  (1, '79'),
#  (1, '7,'),
#  (1, '7'),
#  (1, '50-year'),
#  (1, '3.6%'),
#  (1, '2020'),
#  (1, '20%'),
#  (1, '2'),
#  (1, '.@SecPompeo'),
#  (1, '.@RichardGrenell'),
#  (1, '.@MikeBloomberg'),
#  (1, '....The'),
#  (1, '(Which,'),
#  (1, '(Comcast'),
#  (1, '$145,000,000'),
#  (1, '$'),
#  (1, '#…'),
#  (1, '#USCGR'),
#  (1, '#KAG2020🇺🇸'),
#  (1, '#JobsReport:'),
#  (1, '#DemocratsHateAmerica'),
#  (1, '#Bla…'),
#  (1, '"reduction'),
#  (1, '"Reduction'),
#  (1, '"Bernie')]

# %%
data12 = []
for tweet in Trump_tweets:
    data12.append(tweet.truncated)
    
print(data12)
# Out:
# [True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, False]

# %%
print("The account was created at: "+str(example_user.created_at))
# Out:
# The account was created at: 2011-05-12 09:31:02

# %%
example_user
# Out:
# User(_api=<tweepy.api.API object at 0x0000016060639488>, _json={'id': 297315854, 'id_str': '297315854', 'name': 'UniversityCopenhagen', 'screen_name': 'uni_copenhagen', 'location': 'Copenhagen, Denmark', 'profile_location': None, 'description': 'About science and innovation at #ucph | Tweets in Danish @koebenhavns_uni | #scicomm', 'url': 'https://t.co/UGnmcIZRCV', 'entities': {'url': {'urls': [{'url': 'https://t.co/UGnmcIZRCV', 'expanded_url': 'http://ku.dk/english/', 'display_url': 'ku.dk/english/', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 9038, 'friends_count': 35, 'listed_count': 187, 'created_at': 'Thu May 12 09:31:02 +0000 2011', 'favourites_count': 297, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 666, 'lang': None, 'status': {'created_at': 'Fri Feb 21 14:42:56 +0000 2020', 'id': 1230865493789216768, 'id_str': '1230865493789216768', 'text': 'Research and education is an international matter. 70 researchers from #UCPH and our five partner universities in… https://t.co/X6ZzR11HqI', 'truncated': True, 'entities': {'hashtags': [{'text': 'UCPH', 'indices': [71, 76]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/X6ZzR11HqI', 'expanded_url': 'https://twitter.com/i/web/status/1230865493789216768', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [115, 138]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 4, 'favorite_count': 18, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '901A1E', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/918209277680062466/J7On-j_X_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/918209277680062466/J7On-j_X_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/297315854/1393427377', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, id=297315854, id_str='297315854', name='UniversityCopenhagen', screen_name='uni_copenhagen', location='Copenhagen, Denmark', profile_location=None, description='About science and innovation at #ucph | Tweets in Danish @koebenhavns_uni | #scicomm', url='https://t.co/UGnmcIZRCV', entities={'url': {'urls': [{'url': 'https://t.co/UGnmcIZRCV', 'expanded_url': 'http://ku.dk/english/', 'display_url': 'ku.dk/english/', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=9038, friends_count=35, listed_count=187, created_at=datetime.datetime(2011, 5, 12, 9, 31, 2), favourites_count=297, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=666, lang=None, status=Status(_api=<tweepy.api.API object at 0x0000016060639488>, _json={'created_at': 'Fri Feb 21 14:42:56 +0000 2020', 'id': 1230865493789216768, 'id_str': '1230865493789216768', 'text': 'Research and education is an international matter. 70 researchers from #UCPH and our five partner universities in… https://t.co/X6ZzR11HqI', 'truncated': True, 'entities': {'hashtags': [{'text': 'UCPH', 'indices':  ...

# %%
print("The account is located at: "+str(example_user.location)+" and the account has "+str(example_user.followers_count)+" followers")
# Out:
# The account is located at: Copenhagen, Denmark and the account has 9038 followers

# %%
ny_user = api.get_user("mfroman")

# %%
ny_user_timeline = api.user_timeline("mfroman")
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-64-03f13696d29f> in <module>
# ----> 1 ny_user_timeline = api.user_timeline("mfroman")
#
# ~\Anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# ~\Anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     231                     raise RateLimitError(error_msg, resp)
#     232                 else:
# --> 233                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     234
#     235             # Parse the response payload
#
# TweepError: Not authorized.

# %%
cph_sodas = api.user_timeline("CPH_sodas")

# %%
len(cph_sodas)
# Out:
# 20

# %%
def user_gist_ny(user_timeline):
    
    # set up empty containers we will need throughout the loop
    word_freq = {}
    word_list = []
    gist = []
    
    # FIRST, loop through tweets in the timeline
    for tweet in user_timeline:
        # split up tweets into lists of words
        tweet_words = tweet.text.split()
        # and combine into one big list using `extend` command
        word_list.extend(tweet_words)
        
    
    # SECOND, loop through list of words in tweets
    for w in word_list:
        # add each unique word and its `count` to the dictionary `word_frequency`
        if w not in word_freq:
            word_freq[w] = word_list.count(w)

    #looping through the dictionary and adding each value, key pair to the list
    for key in word_freq:
        gist.append((word_freq[key], key))

    #sorting the list
    gist.sort()
    #reversing the sort to be largest to smallest
    gist.reverse()

    #returning the list
    return gist

# %%
user_gist(cph_sodas)
# Out:
# [(10, 'RT'),
#  (5, '@distractdenmark:'),
#  (5, '#machineanthropology'),
#  (4, 'workshop'),
#  (3, 'social'),
#  (3, 'series'),
#  (3, 'first'),
#  (3, 'Morten'),
#  (3, 'Axel'),
#  (3, '@suneman'),
#  (3, '&amp;'),
#  (2, 'the…'),
#  (2, 'talk'),
#  (2, 'stage'),
#  (2, 'science'),
#  (2, 'new'),
#  (2, 'media'),
#  (2, 'commenting'),
#  (2, 'The'),
#  (2, 'Pedersen'),
#  (2, 'Machine'),
#  (2, 'MSc'),
#  (2, 'Join'),
#  (2, 'In'),
#  (2, '@andbjn:'),
#  (2, '@RebAdlerNissen'),
#  (2, '@CPH_SODAS'),
#  (1, "📲'Politikere"),
#  (1, 'widely'),
#  (1, 'well-off'),
#  (1, 'want'),
#  (1, 'visited'),
#  (1, 'verdens'),
#  (1, 'various'),
#  (1, 'using'),
#  (1, 'use'),
#  (1, 'us'),
#  (1, 'two'),
#  (1, 'transfer'),
#  (1, 'tools?'),
#  (1, 'thing'),
#  (1, 'talks'),
#  (1, 'surrounding'),
#  (1, 'study'),
#  (1, 'spring'),
#  (1, 'spread'),
#  (1, 'speakers'),
#  (1, 'social…'),
#  (1, 'second'),
#  (1, 'scientist'),
#  (1, 'school'),
#  (1, 'revolves'),
#  (1, 'research.'),
#  (1, 'redrawing'),
#  (1, 'reactions'),
#  (1, 'questio…'),
#  (1, 'question'),
#  (1, 'på'),
#  (1, 'project'),
#  (1, 'prog…'),
#  (1, 'program'),
#  (1, 'professor'),
#  (1, 'problem?'),
#  (1, 'presentations'),
#  (1, 'pres'),
#  (1, 'predicting'),
#  (1, 'politics'),
#  (1, 'piece'),
#  (1, 'perspectives'),
#  (1, 'people'),
#  (1, 'participated'),
#  (1, 'og'),
#  (1, 'next'),
#  (1, 'neighborh…'),
#  (1, 'mobil'),
#  (1, 'mixing'),
#  (1, 'miss'),
#  (1, 'misinformation?'),
#  (1, 'might'),
#  (1, 'meth…'),
#  (1, 'methods.'),
#  (1, 'lecture'),
#  (1, 'kids'),
#  (1, 'joint'),
#  (1, 'it?'),
#  (1, 'issue).'),
#  (1, 'invited'),
#  (1, 'international'),
#  (1, 'interesting'),
#  (1, 'images,'),
#  (1, 'https://t.co/hi2vClmf3e'),
#  (1, 'https://t.co/b54dD3HmjC'),
#  (1, 'https://t.co/YvqlQOqFsR'),
#  (1, 'https://t.co/XvslIriVf4'),
#  (1, 'https://t.co/VE1Q1BQsrW'),
#  (1, 'https://t.co/UWN9LsZccd'),
#  (1, 'https://t.co/KaoRrJUG0e'),
#  (1, 'https://t.co/EKO5wosjo1'),
#  (1, 'https://t.co/Arg6Mbg8ms'),
#  (1, 'https://t.co/72RDrSqX…'),
#  (1, 'https://t.co/62KsL3j8cY'),
#  (1, 'https://t.co/5Emhm5xdNx'),
#  (1, 'https://t.co/2FGpnRtu6Y'),
#  (1, 'host'),
#  (1, 'hele'),
#  (1, 'grant!'),
#  (1, 'good'),
#  (1, 'front'),
#  (1, 'forhandlingsrummet'),
#  (1, 'forhandler'),
#  (1, 'foran'),
#  (1, 'fellow'),
#  (1, 'even'),
#  (1, 'episode'),
#  (1, 'emotions'),
#  (1, 'emojis,'),
#  (1, 'diplomats'),
#  (1, 'developments'),
#  (1, 'decrease'),
#  (1, 'dealing'),
#  (1, 'de'),
#  (1, 'day’s'),
#  (1, 'days'),
#  (1, 'data'),
#  (1, 'co…'),
#  (1, 'computational'),
#  (1, 'compa…'),
#  (1, 'combining'),
#  (1, 'colleague…'),
#  (1, 'colleagues.'),
#  (1, 'co-organized'),
#  (1, 'centered'),
#  (1, 'både'),
#  (1, 'boundaries'),
#  (1, 'bots'),
#  (1, 'befolkning'),
#  (1, 'be?'),
#  (1, 'back'),
#  (1, 'awarded'),
#  (1, 'attendance'),
#  (1, 'aspects'),
#  (1, 'article'),
#  (1, 'aroun…'),
#  (1, 'around'),
#  (1, 'are…'),
#  (1, 'ans…'),
#  (1, 'affect'),
#  (1, 'address'),
#  (1, 'Willadsen'),
#  (1, 'Why'),
#  (1, 'Who'),
#  (1, 'What'),
#  (1, 'Vincent'),
#  (1, 'UCPH'),
#  (1, 'Turns'),
#  (1, 'This'),
#  (1, 'Thick'),
#  (1, 'Testing'),
#  (1, 'Sune'),
#  (1, 'Spring'),
#  (1, 'Social'),
#  (1, 'Series'),
#  (1, 'Say'),
#  (1, 'Sapienza'),
#  (1, 'SODAS'),
#  (1, 'Rebecca'),
#  (1, 'Ray…'),
#  (1, 'Prof.'),
#  (1, 'Phillip'),
#  (1, 'PhD'),
#  (1, 'Peter'),
#  (1, 'Pedersen,'),
#  (1, 'Passionate'),
#  (1, 'Our'),
#  (1, 'Nicolajsen'),
#  (1, 'News'),
#  (1, 'Networks'),
#  (1, 'Nature'),
#  (1, 'Monday.'),
#  (1, 'Monday'),
#  (1, 'Lehmann'),
#  (1, 'Kristin'),
#  (1, 'Kelton'),
#  (1, 'I❤️@RISjnl'),
#  (1, 'Information'),
#  (1, 'Hendricks'),
#  (1, 'Helene'),
#  (1, 'Hear'),
#  (1, 'Halkier'),
#  (1, 'For'),
#  (1, "Don't"),
#  (1, 'Discussion'),
#  (1, 'December'),
#  (1, 'Data+'),
#  (1, 'Data'),
#  (1, 'DISTRACT'),
#  (1, 'Copenhagen.…'),
#  (1, 'Chinese'),
#  (1, 'Check'),
#  (1, 'Can'),
#  (1, 'Bubbles'),
#  (1, 'Brooker'),
#  (1, 'Anthropology'),
#  (1, 'Anna'),
#  (1, 'And'),
#  (1, 'Anabel'),
#  (1, 'Adler-Nissen'),
#  (1, 'AI,'),
#  (1, 'A'),
#  (1, '@fmerhout'),
#  (1, '@daviddlassen,'),
#  (1, '@daviddlassen'),
#  (1, '@TANTlab:'),
#  (1, '@RebAdlerNissen:'),
#  (1, '@RebAdlerNissen,'),
#  (1, "@It_vest's"),
#  (1, '@Golovchenko_Yev'),
#  (1, '@DIP…'),
#  (1, '@Carlsbergfondet:'),
#  (1, '@CPH_SODAS.'),
#  (1, '@AndersKMunk'),
#  (1, '2020'),
#  (1, '(and'),
#  (1, '(1/7)'),
#  (1, "'thick'…"),
#  (1, '#thickmachine'),
#  (1, '#segregation?')]

# %%
search_pattern = "Braithwaite"

new_tweets = api.search(search_pattern, count = 10)

users_data = []

for tweet in new_tweets:
    users_data.append((tweet.created_at, tweet.text))

# %%
users_data
# Out:
# [(datetime.datetime(2020, 2, 22, 19, 7, 21),
#   'RT @brfootball: Martin Braithwaite makes his Barca debut 🔵🔴 https://t.co/PSlKtLHd7L'),
#  (datetime.datetime(2020, 2, 22, 19, 7, 20),
#   'RT @EdmundOris: Martin Braithwaite just wants to play for Barça\nSpend time with The goat 🐐, learn a thing or two from him,play football, sc…'),
#  (datetime.datetime(2020, 2, 22, 19, 7, 18),
#   'RT @totalBarca: Incredible debut.\n\nEnergy, energy and energy.\n\nMartin Braithwaite, take a bow. https://t.co/A4MfLZ58jS'),
#  (datetime.datetime(2020, 2, 22, 19, 7, 18),
#   "RT @WinamaxSport: Messi quand Braithwaite l'a checké dans le vestiaire pour le féliciter. https://t.co/LUyiDq5b3K"),
#  (datetime.datetime(2020, 2, 22, 19, 7, 17),
#   'RT @FrenkismoFCB: Fuera coñas, Braithwaite es bueno y nos va ayudar muchísimo.'),
#  (datetime.datetime(2020, 2, 22, 19, 7, 17),
#   "RT @WinamaxSport: Messi quand Braithwaite l'a checké dans le vestiaire pour le féliciter. https://t.co/LUyiDq5b3K"),
#  (datetime.datetime(2020, 2, 22, 19, 7, 14),
#   'RT @goal: ⚽️ Messi\n⚽️ Messi\n⚽️ Messi\n⚽️ Messi\n\n🅰️ Braithwaite\n🅰️ Braithwaite\n\nDream team 🌟 https://t.co/35TmFmzk7R'),
#  (datetime.datetime(2020, 2, 22, 19, 7, 14),
#   'RT @Joshua_Ubeku: No one believed in Chris Brown Braithwaite but less that 15 minutes of playing, he assisted Messi’s 4th goal. Funny how i…'),
#  (datetime.datetime(2020, 2, 22, 19, 7, 10),
#   'RT @BarcaBot10: Braithwaite has the same amount of assists as ronaldo all season now. It’s only taken him 1 game. goat https://t.co/Q7kZhFj…'),
#  (datetime.datetime(2020, 2, 22, 19, 7, 9),
#   'RT @brfootball: 2 assists in 18 minutes\n\nMartin Braithwaite got right to work on his debut 🤝 https://t.co/7HU9ie5Wym')]
